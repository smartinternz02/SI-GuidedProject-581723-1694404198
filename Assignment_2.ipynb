# %% [markdown]
# <a href="https://colab.research.google.com/github/NNitin29/Assignment1/blob/main/Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Download the dataset: Dataset

# %% [markdown]
# N.NITIN 21BCE5165

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns

# %% [markdown]
# 2.Load the dataset

# %%
df=pd.read_csv('/content/House Price India.csv')
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
colum=['id','Date','number of bedrooms','Area of the house(excluding basement)']

# %%
df=pd.read_csv('/content/House Price India.csv',usecols=colum)
df.head
# Out:
# <bound method NDFrame.head of                id   Date  number of bedrooms  \
# 0      6762810145  42491                   5
# 1      6762810635  42491                   4
# 2      6762810998  42491                   5
# 3      6762812605  42491                   4
# 4      6762812919  42491                   3
# ...           ...    ...                 ...
# 10047  6762818471  42645                   4
# 10048  6762818613  42645                   3
# 10049  6762818676  42645                   4
# 10050  6762819138  42645                   4
# 10051  6762819907  42645                   4
#
#        Area of the house(excluding basement)
# 0                                       3370
# 1                                       1910
# 2                                       2910
# 3                                       3310
# 4                                       1880
# ...                                      ...
# 10047                                   3130
# ...

# %% [markdown]
# Univariate analysis

# %%
df['Area of the house(excluding basement)'].describe()
# Out:
# count    10052.000000
# mean      1810.773179
# std        833.480485
# min        370.000000
# 25%       1200.000000
# 50%       1590.000000
# 75%       2252.500000
# max       9410.000000
# Name: Area of the house(excluding basement), dtype: float64

# %%
plt.pie(df['number of bedrooms'].value_counts())
plt.show()

# %%
sns.histplot(df['Area of the house(excluding basement)'], kde=True)
plt.title('Histogram of Area of the house(excluding basement)')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# %%
sns.boxplot(x='Area of the house(excluding basement)', data=df)
plt.title('Box Plot of Area of the house(excluding basement)')
plt.xlabel('Area of the house(excluding basement)')
plt.show()

# %%
sns.countplot(x='Area of the house(excluding basement)', data=df)
plt.title('Count Plot of Area of the house(excluding basement)')
plt.xlabel('Area of the house(excluding basement)')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Bivariate analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a scatter plot
plt.figure(figsize=(8, 6))  # Set the figure size (optional)
sns.scatterplot(x='number of bedrooms', y='Area of the house(excluding basement)', data=df)
# Out:
# <Axes: xlabel='number of bedrooms', ylabel='Area of the house(excluding basement)'>

# %%
correlation = df['number of bedrooms'].corr(df['Area of the house(excluding basement)'])
print(f"Correlation between number of bedrooms and Area of the house(excluding basement) : {correlation}")
# Out:
# Correlation between number of bedrooms and Area of the house(excluding basement) : 0.4634841074166373

# %%
plt.figure(figsize=(8, 6))  # Set the figure size (optional)
sns.boxplot(x='number of bedrooms', y='Area of the house(excluding basement)', data=df)
# Out:
# <Axes: xlabel='number of bedrooms', ylabel='Area of the house(excluding basement)'>

# %% [markdown]
# Multivariate analysis

# %%
selected_columns = ['Date','number of bedrooms','Area of the house(excluding basement)']
sns.pairplot(df[selected_columns])
plt.show()

# %%
correlation_matrix = df[selected_columns].corr()

# Create a heatmap of the correlation matrix
plt.figure(figsize=(10, 8))  # Set the figure size (optional)
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# Descriptive analysis  on the dataset

# %%
df.describe() # descriptive analysis
# Out:
#                  id          Date  number of bedrooms  \
# count  1.005200e+04  10052.000000        10052.000000
# mean   6.762821e+09  42567.248806            3.386092
# std    6.212973e+03     43.226800            0.945146
# min    6.762810e+09  42491.000000            1.000000
# 25%    6.762815e+09  42531.000000            3.000000
# 50%    6.762821e+09  42566.000000            3.000000
# 75%    6.762826e+09  42603.000000            4.000000
# max    6.762832e+09  42645.000000           33.000000
#
#        Area of the house(excluding basement)
# count                           10052.000000
# mean                             1810.773179
# std                               833.480485
# min                               370.000000
# 25%                              1200.000000
# 50%                              1590.000000
# 75%                              2252.500000
# max                              9410.000000

# %% [markdown]
# Handling the missing values

# %%
df.isnull().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# Area of the house(excluding basement)    0
# dtype: int64

# %%
df.dropna(inplace=True)
df.dropna()
# Out:
#                id   Date  number of bedrooms  \
# 0      6762810145  42491                   5
# 1      6762810635  42491                   4
# 2      6762810998  42491                   5
# 3      6762812605  42491                   4
# 4      6762812919  42491                   3
# ...           ...    ...                 ...
# 10047  6762818471  42645                   4
# 10048  6762818613  42645                   3
# 10049  6762818676  42645                   4
# 10050  6762819138  42645                   4
# 10051  6762819907  42645                   4
#
#        Area of the house(excluding basement)
# 0                                       3370
# 1                                       1910
# 2                                       2910
# 3                                       3310
# 4                                       1880
# ...                                      ...
# 10047                                   3130
# 10048                                   1480
# ...
