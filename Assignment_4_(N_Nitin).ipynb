# %% [markdown]
# <a href="https://colab.research.google.com/github/smartinternz02/SI-GuidedProject-581723-1694404198/blob/main/Assignment_4_(N_Nitin).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nitin 21BCE5165

# %% [markdown]
# 1.Load the Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("/content/winequality-red.csv")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# 2.Data preprocessing including visualization

# %%
fig = plt.figure(figsize=(18,20))
for index, column in enumerate(list(df.columns)):
    if column!="quality":
        plt.subplot(6,2,index+1)
        sns.histplot(df[column], kde=True)
fig.tight_layout(pad=1)

# %%
fig = plt.figure(figsize=(16,17))
for index, column in enumerate(list(df.columns)):
    if column!="quality":
        plt.subplot(6,4,index+1)
        sns.boxplot(y=column, data=df)
fig.tight_layout(pad=2)

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
sns.boxplot(df["residual sugar"])
# Out:
# <Axes: >

# %%
q1 = df["residual sugar"].quantile(0.25)
q3 = df["residual sugar"].quantile(0.75)
print(q1)
print(q3)
# Out:
# 1.9
# 2.6

# %%
IQR = q3-q1
IQR
# Out:
# 0.7000000000000002

# %%
upper_limit = q3+2.5*IQR
upper_limit
# Out:
# 4.3500000000000005

# %%
lower_limit = q1-2.5*IQR
lower_limit
# Out:
# 0.14999999999999947

# %%
df.median()
# Out:
# fixed acidity            7.90000
# volatile acidity         0.52000
# citric acid              0.26000
# residual sugar           2.20000
# chlorides                0.07900
# free sulfur dioxide     14.00000
# total sulfur dioxide    38.00000
# density                  0.99675
# pH                       3.31000
# sulphates                0.62000
# alcohol                 10.20000
# quality                  6.00000
# dtype: float64

# %%
df['residual sugar'] = np.where(df['residual sugar']>upper_limit,2.2,df['residual sugar'])
sns.boxplot(df['residual sugar'])
# Out:
# <Axes: >

# %%
fig = plt.figure(figsize=(16,17))
for index, column in enumerate(list(df.columns)):
    if column!="quality":
        plt.subplot(6,4,index+1)
        sns.boxplot(y=column, data=df)
fig.tight_layout(pad=2)

# %%
meds = list(df.median())
for index, column in enumerate(list(df.columns)):
    if index==3:
        continue
    elif index==11:
        continue
    else:
        q1 = df[column].quantile(0.25)
        q3 = df[column].quantile(0.75)
        IQR = q3-q1
        upper_limit = q3+1.5*IQR
        lower_limit = q1-1.5*IQR
        df[column] = np.where(df[column]>upper_limit,meds[index],df[column])
fig = plt.figure(figsize=(16,17))
for index, column in enumerate(list(df.columns)):
    if column!="quality":
        plt.subplot(6,4,index+1)
        sns.boxplot(y=column, data=df)
fig.tight_layout(pad=2)

# %%
plt.bar(df.chlorides.value_counts(),df.chlorides.value_counts())
plt.title("Chlorides")
plt.show()

# %%
sns.jointplot(x="density",y="quality",data=df)
plt.show()

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# 3.Machine Learning Model Building

# %%
X = df.drop(columns=['quality'], axis=1)
y = df['quality']
X.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4

# %%
y.head()
# Out:
# 0    5
# 1    5
# 2    5
# 3    6
# 4    5
# Name: quality, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size=0.33)
from sklearn.preprocessing import StandardScaler

sc =StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)
LogisticRegression()
# Out:
# LogisticRegression()

# %%
pred = model.predict(X_test)
pred
# Out:
# array([5, 5, 6, 6, 7, 6, 6, 5, 6, 5, 6, 5, 5, 7, 6, 5, 6, 5, 6, 5, 6, 6,
#        5, 7, 5, 6, 6, 5, 5, 5, 5, 7, 5, 6, 5, 6, 5, 5, 6, 5, 6, 5, 5, 6,
#        5, 6, 5, 5, 5, 6, 5, 5, 6, 5, 5, 6, 6, 6, 7, 5, 6, 5, 5, 5, 5, 5,
#        7, 6, 6, 6, 5, 6, 6, 6, 6, 5, 6, 5, 5, 6, 6, 5, 5, 5, 6, 5, 5, 6,
#        5, 6, 5, 6, 5, 6, 6, 5, 6, 5, 5, 6, 6, 5, 5, 5, 5, 5, 6, 5, 6, 7,
#        6, 6, 6, 5, 5, 7, 5, 5, 5, 5, 5, 7, 6, 5, 5, 5, 6, 5, 7, 6, 6, 5,
#        6, 5, 6, 6, 5, 7, 5, 5, 5, 5, 6, 5, 6, 7, 6, 5, 6, 6, 5, 7, 5, 5,
#        6, 6, 6, 6, 6, 6, 6, 6, 5, 5, 6, 6, 6, 5, 5, 6, 5, 6, 5, 5, 7, 5,
#        5, 5, 5, 5, 6, 6, 6, 5, 6, 7, 6, 6, 4, 5, 5, 5, 5, 5, 6, 5, 6, 6,
#        5, 5, 6, 6, 6, 5, 7, 6, 5, 5, 6, 6, 5, 6, 5, 6, 5, 5, 5, 5, 6, 5,
#        6, 5, 5, 5, 6, 6, 6, 6, 7, 6, 5, 5, 6, 6, 5, 5, 6, 5, 6, 6, 6, 6,
#        6, 5, 5, 7, 6, 5, 5, 5, 5, 5, 6, 6, 6, 5, 5, 5, 5, 6, 6, 5, 6, 5,
#        5, 6, 6, 5, 5, 6, 5, 6, 5, 6, 5, 6, 5, 6, 5, 5, 7, 6, 6, 5, 5, 6,
# ...

# %% [markdown]
# 4.Evaluation metrics

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
X=df.drop("quality",axis=1)
y=df["quality"]
X.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4

# %%
sc=StandardScaler()
X_scaled=sc.fit_transform(X)
X_train,X_test,y_train,y_test=train_test_split(X_scaled,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
le=LogisticRegression()
model=le.fit(X_train,y_train)
y_pred = model.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# array([[ 0,  0,  1,  0,  0,  0],
#        [ 0,  1,  7,  2,  0,  0],
#        [ 0,  0, 98, 32,  0,  0],
#        [ 0,  0, 46, 76, 10,  0],
#        [ 0,  0,  3, 30,  9,  0],
#        [ 0,  0,  0,  1,  4,  0]])

# %%
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,roc_auc_score,roc_curve
accuracy_score(y_test,y_pred)
# Out:
# 0.575

# %%
pd.crosstab(y_test,y_pred)
# Out:
# col_0    4   5   6   7
# quality
# 3        0   1   0   0
# 4        1   7   2   0
# 5        0  98  32   0
# 6        0  46  76  10
# 7        0   3  30   9
# 8        0   0   1   4

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         1
#            4       1.00      0.10      0.18        10
#            5       0.63      0.75      0.69       130
#            6       0.54      0.58      0.56       132
#            7       0.39      0.21      0.28        42
#            8       0.00      0.00      0.00         5
#
#     accuracy                           0.57       320
#    macro avg       0.43      0.27      0.28       320
# weighted avg       0.56      0.57      0.55       320
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# 5.Test with random observation

# %%
model.predict([[7.4, 0.700, 0.00, 1.9, 0.076, 11.0, 34.0, 0.99780, 3.51, 0.56, 9.4]])
# Out:
# array([5])
